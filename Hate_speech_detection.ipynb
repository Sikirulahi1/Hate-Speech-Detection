# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/NLP/HateSpeechDetection/Data/HateSpeechDatasetBalanced.csv")
df
# Out:
#                                                   Content  Label
# 0       denial of normal the con be asked to comment o...      1
# 1       just by being able to tweet this insufferable ...      1
# 2       that is retarded you too cute to be single tha...      1
# 3       thought of a real badass mongol style declarat...      1
# 4                                     afro american basho      1
# ...                                                   ...    ...
# 726114  i mute this telecasting and played kanye west ...      1
# 726115  but hell yeah he s not a bachelor but looooooo...      1
# 726116  great video musician but s not my musician lol...      1
# 726117  not great pop video yeah he s not a pedophile ...      1
# 726118  great video yeah he s non a paedophile lolllll...      1
#
# [726119 rows x 2 columns]

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# Content    0
# Label      0
# dtype: int64

# %% [markdown]
# # Work flow
#
# - Split values into X and y and create a copy from it to be cleaned
# - Clean the text using WordNetLematizer and using the stopwords to remove redundant texts
# - Create a one_hot_representation from it.
# - Create a pre-padding to it using the `pad_sequence`
# - Return the model back to form a set of independent variable.
# - Splt the dataset into train and validate.
# - Train the model.
# - Carry out inferences

# %% [markdown]
# ## Splitting the dataset into dependent and independent

# %%
X = df['Content']
y = df['Label']

# %%
messages = X.copy()

# %% [markdown]
# ## Preprocessing the dataset and applying lematization

# %%
messages[1]
# Out:
# 'just by being able to tweet this insufferable bullshit proves trump a nazi you vagina'

# %%
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import re

nltk.download('stopwords')
nltk.download('wordnet')
lematizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
corpus = []

for i in range(0, len(messages)):
  result = messages[i]
  # We remove all the special characters and the numbers
  result = re.sub('[^A-Za-z]', ' ', messages[i])
  # We make sure it is in lower case
  result = result.lower().split()
  result = [lematizer.lemmatize(word) for word in result if not word in stopwords.words('english')]
  result = ' '.join(result)

  corpus.append(result)

# %%
corpus
# Out:
# ['denial normal con asked comment tragedy emotional retard',
#  'able tweet insufferable bullshit prof trump nazi vagina',
#  'retarded cute single life',
#  'thought real badass mongol style declaration war attacker capture citizen soon',
#  'afro american basho',
#  'yeah retard haha',
#  'ching chong chung stuff',
#  'dead slut still warm tweeted slut vagina mate obama sent fucking lowlife',
#  'let tweet harmless affect way faggot one n',
#  'latino problem immigration enforcement stay shithole',
#  'feel much secondhand embarrassment white person call ppi milo say spic like want move',
#  'got gorgeous figure unfunny twat',
#  'vile vagina',
#  'oh shut twat',
#  'fucking retard twat chop',
#  'fucking faggot',
#  'holy shit faggot laughing as',
#  'hate man laughing as go live life sour vagina stay spectating',
#  'country honest god shithole fuck irrelevant foreigner former leader murder capital',
#  'use cup mongoloid',
#  'oh said nun mean cool k afro american',
#  'fuck vagina fuck mike ashley prick nfc',
#  'heard phrase since middle school',
#  'pruitt retarded aight',
#  'bitch talked shit ya know said would say well um hm daily retard',
#  'faggot',
#  'gone full retard supposed go full lady gentleman l need new friend',
#  'definitely used mumble nigger breath dak missed problem day',
#  'unfollow part baby dyke twitter',
#  'well pay phone world mongoloid',
#  'honestly hate get angry people say chink ching chong seeing cong whatever fuck',
#  'simple answer deport reduce next aid payment somalia amount',
#  'oui je comp rends parent side pourquoi crux quit violent actually le migrant n en present pa',
#  'know feminazi psycho want take',
#  'retarded',
#  'cupcake code retard retweeted alternate account commented main',
#  'group grown men supplied amazing customer service today called',
#  'vagina dressed hard cunt hard cunt cunt good costume cunt',
#  'blah blah ching chong eat dog',
#  'accent funny fucking retard',
#  'thinking glad spic dead',
#  'neil lennon soup taker haha kin hell',
#  'mongol dream',
#  'laughing loud let know fact ching chong hurt',
#  'shut year old lame as dyke',
#  'state backwards shithole last education every category stop pretending',
#  'cheating vagina admitted handled ball score typical leeds cunt nfc lfc',
#  'sweden reacts outnumbered immigrant',
#  'doreen snack return room find everything spic span including clothes',
#  'negra novena cavalcade oh afro american pseudo',
#  'actually retarded',
#  'begs question obama year help',
#  'guess happens allow people invade country become',
#  'starving faggot starving faggot dad thought family playing game',
#  'lot smaller payment time faggot credit card could handle hit still',
#  'good morning ching chong',
#  'wapking big sexy photo dylan ryder afro american',
#  'told slut retarded',
#  'never forget niggaz retarded',
#  'like mongoloid better anyway',
#  'oh poor deluded one matter much drink cool aid always spic',
#  'please stop putting cancer twitter retard',
#  'bandri go back country pakistan country afghanistan',
#  'using bomb intimidate voter common shithole country sad day mailbombed',
#  'men created africa theory marcus garvey slut agent funded schooled called jew',
#  'good job bantu as bet even know',
#  'governor brown vetoed senator ricardo lara bill sb would allowed illegal alien serve b',
#  'get preterit going punch stomach retarded',
#  'really pauline hanson okay white thing like tip garbage genocide iceberg',
#  'new neighbor dyke realized peek house door open come',
#  'fuck talking fat four eyed fucking retard',
#  'population undocumented immigrant widely thought around million study slut con',
#  'listening afro american swan',
#  'london fan hate fat vagina mean time office gun n rose',
#  'call singing vagina would get four performance got likability',
#  'need cool cowhide coat extraordinary event dwayne johnson baywatch lifeguard jacket spic',
#  'ching chong bing bong eat dog',
#  'well china get wrecked mongol japan repel mongol assault twice',
#  'retarded going get cheese touch',
#  'please charlene welcome shithole helped created supporting',
#  'hate nigga really think entertain conversation dyke fuck move year old goofy as around nigga',
#  'breed',
#  'think sport entertainment culture stupid cunt',
#  'daft',
#  'love term feminazis mind use funny always cry',
#  'called son retarded call son',
#  'thank god america like free speech free shithole country europe keep america different',
#  'faggot',
#  'leicester like cheese fucking yobbo cunt',
#  'go hardy go retarded',
#  'rag head camel swagger',
#  'pm iranian expressed desire give pakistani nationality afghan bengali refugee',
#  'ever making call pretty retarded learn mistake',
#  'never hit woman load stella artist iron vest vagina make exception',
#  'laughing loud hey man started writing ching chong first okay www also know',
#  'government water world shithole country regulation based solution',
#  'thanks historic taco bowl signed law crooked hillary going shithole',
#  'best television watch lot tv probably malamute care faggot shit slut good',
#  'sgt crazy retarded impossible time hack pt cop back b co minute fall',
#  'straight girl go hamburger mary start thinking say faggot',
#  'faggot else get face',
#  'fucking retard gave best ammunition possible',
#  'hey know say retard many time short amount word make look retarded',
#  'adderall slut cool could retarded efficiently',
#  'shutup nigger',
#  'mean tell called cracker carry weight called nigger spick wetback',
#  'king please forgive mean laugh mongoloid',
#  'go one day without seeing faggot phone',
#  'right fair seem attract money element gig',
#  'fuck faggot',
#  'funny use mean cool k slut responsible murder',
#  'blown holding call slut short god ref retarded',
#  'still master ceremony rag head',
#  'supra fucking faggot',
#  'another silly cunt twitter full',
#  'think retarded mutual possibly never',
#  'found envelope say ching chong',
#  'cannot believe ching chong point',
#  'name ching chong assume name',
#  'okay white',
#  'remember going every dinner slut wee yobbo david lister frown sad andy pouting man spicy salt',
#  'said word fucking mongoloid',
#  'yuki kick vagina stop talking two',
#  'hey stinky dyke tslint',
#  'fuck rich hill faggot',
#  'call faggot agree somewhat agree disagree',
#  'congratulation dumb vagina',
#  'really thinking like nigga think dumb must think retarded',
#  'afrikaans dumb vagina speak',
#  'post video sweating pub killing someone trying play casual faggot sorry sorry',
#  'whenever say give aid much posh vagina',
#  'left go nut call country insisting country shithole',
#  'think finally year fucking cunt',
#  'fucking vagina',
#  'call australian government expand improve community sponsorship refugee family',
#  'get head fixed first',
#  'walk gate faggot detector go',
#  'united state america morph heartless shithole country trump administration vote democrat voted',
#  'fuck spic mean offensive',
#  'say retard beehive size apartment',
#  'never agreed anything donald trump called african country shithole',
#  'could point come shithole country whatever know feel phrase',
#  'leader free world anymore twat expletive suppressed',
#  'leaving shithole country turn europe continent full shithole country home',
#  'america favor stop giving hateful leftist reporter privilege',
#  'one girl chinese whenever educates girl say ching chong shit girl go',
#  'fucking vagina joke',
#  'disgusting tweet vile cunt',
#  'hyaaaa tremble ching chong',
#  'hol mean time famous weird k pop ching chong night like cannot even argue bro even de',
#  'hole sir faggot sir clit sir hole sir faggot sir clit sir',
#  'tyrone retarded',
#  'fucking',
#  'good old spicy meme made decided little vagina happy face smiley',
#  'calling vagina probably',
#  'nigera fucker nigger proper',
#  'shut fuck come party retard',
#  'ching chong ching chang',
#  'kelly rowland really called freddie kruger faggot lmaoooooooooooo',
#  'people go instant retard told firmly leave',
#  'asian group ching chong dog eater chinese dude',
#  'luke retarded need better job rotation stop calling dumb timeouts',
#  'faggot paying new underwear message',
#  'wait never mind retarded got one seth',
#  'go finish sentence mongol',
#  'ching chong',
#  'gay gay gay hate filthy faggot love joost jew maccabees era hate',
#  'anonymous faggot',
#  'nigger',
#  'man got louisville nigger museum fucking funny god damn',
#  'buying rag head vote see',
#  'mother first crazy retarded as bitch right',
#  'feminazi sorry know feminist crazy',
#  'damn got called nigger today',
#  'get mate sickening especially ching chong bastard',
#  'shaking head woman really retarded',
#  'ok laughing as twitch abandoned faggot',
#  'herman certified faggot life tonight grundy showed fact grundy slut pissed',
#  'get eg away keyboard team tax like mongol tax',
#  'glad talked acting retarded',
#  'uhhh stupid faggot goblin slayer actually make sense',
#  'white girl busits okay didnt say nigger often',
#  'faggot bus driver driving like fuck',
#  'dude wayne said keep mind im afro american open mind got screen door',
#  'retard fighting court pic',
#  'yet administration want curb legal immigration wanting immigrant',
#  'booster moron like literally retarded another toxic young kid go vibe little',
#  'slimy maybe spic boring could never boring suck',
#  'biggest talking hayley mcqueen awful presenter kris common soup',
#  'remove emoji faggot',
#  'nobody asked faggot',
#  'wow headshot kid really immature huh kid neville told brother slut mother passed away',
#  'people stop massacre shooting future getting rid trump retard',
#  'non main genre blague sur le migrant je l time plus en plus',
#  'guy want eat fat dick go figure jump mention faggot as butt hurt whatever lost',
#  'take ucl l stop worrying thing hazijafika ati ooh washed veteran ooh ching chong fucking',
#  'ask rag head buddy body autopsy performed khashoggi',
#  'twat imagine',
#  'bns complete mongoloid come gameplay design idea see bfv attrition regular work good',
#  'nothing retarded love capo agree opinion',
#  'sound faggot',
#  'ask u ask vagina mate white hoist',
#  'vagina probably right lfc',
#  'afro american crazy know many people reach behalf lmao care',
#  'wayne said keep mind afro american open mind screen doe',
#  'retard next started playing eminem new album',
#  'went full retard never go',
#  'faggot prime',
#  'wow face tonight looked like got shit retarded hippopotamus got ran',
#  'dave robert showing good ucla education fucking retard',
#  'paying rag head as make idiotic statement like natural breastfeeding',
#  'fuck fucking wetback spic',
#  'fuck olive slimy as sweaty retard grape',
#  'retard highest horse flinging insult like chimpanzee flinging shit',
#  'learn spell money',
#  'since obama took office illegal alien innocent proven guilty let go welfare benefit',
#  'sleeping schedule retarded',
#  'shut chink spic go suck mom redneck',
#  'hey bud wanted kindly tell complete fucking retard',
#  'fucking retard right run',
#  'refugee middle cross u border',
#  'point tell fucking brilliant retarded completely average guess time',
#  'also cho chang last name thanks picking slight variation ching chong one',
#  'grow retard',
#  'never proven mean time hit woman talent iggy zeal rap like mongoloid',
#  'alex jones attack sandy hook victim company say guy huge vagina spread',
#  'nigger chip kelly ruined everything',
#  'twitter rat tweet twat tripe gob muck run first stanza carol',
#  'one right come country shithole stand',
#  'retard',
#  'next willie redheaded stupid scottish cunt',
#  'elephant eat pound day retard hhh okay',
#  'people soon learn really retarded play deal',
#  'q gave u reddit refugee invitation new home helped',
#  'happy birthday talented mongol wish best miss die take care gba',
#  'end work till hosting laughing phone look like retard know laugh cute quite',
#  'fuck joe retarded notion',
#  'slut ra someone posted okay white poster everywhere ripped shit laughing loud',
#  'oh fucking twat',
#  'good thing donald trump never vilifies democrat group muslim mexican resident country',
#  'vagina better change mind stay fuck away',
#  'game boy advanced opening screen mongoloid',
#  'walk around attacking people call someone mongoloid course choose mean cool k',
#  'want talk immigrant child missing k',
#  'even name twitch fucking retarded even comprehend stupid',
#  'would automatic car total fucking mongoloid chase',
#  'baby faggot stop getting black balled',
#  'france germany britain sweden no shithole country',
#  'added video playlist golden visa wealthy immigrant abuse quebec immigration',
#  'oh suitor impressed chimp broad speak uneducated low info',
#  'savannah go ahead catching charge since afro american',
#  'legitimate might retarded',
#  'yes demonstrates point mentioning turkey sandwich made retard',
#  'thought would interesting remembered jensen bigger literal retard cooooooourse',
#  'slut read social medium post hated refugee',
#  'laughing loud anxiety attack day haha faggot',
#  'called brain dead retard card guardian thought',
#  'side duh politically retarded ng know nothing',
#  'know didnt say kind curl boy doesnt know afro american hair',
#  'best part slut someone called mongoloid',
#  'fucking retarded',
#  'got mom buy headphone really fuck animal as killed faggot',
#  'stop lying leftist micah xavier johnson fired group police officer',
#  'difference nigger nigga former fascist latter shout home bohr',
#  'give refugee give better life',
#  'typical nigger',
#  'know spell retard wear',
#  'stop watching sport faggot',
#  'wrong fucking retard',
#  'started drinking yet faggot as unicorn',
#  'truly shithole country',
#  'share wealth history wealthy pissing well bring disease destruction',
#  'bejarano faggot',
#  'right retard',
#  'would say fucking retarded think retard came told',
#  'hate walk past fellow nigger say head nod unity bruh',
#  'fucking retard',
#  'slut retard asylum day god jet day mix hopeful since long crossed finish line',
#  'kanye dude fuck ching chong shit',
#  'usa becomes shithole country illegal uncontrolled immigration distant',
#  'white trash spice',
#  'bet vagina slut night banging away flute',
#  'come bic ching chong',
#  'liking ireland uk insists continuing make shithole least serve',
#  'many abu dhabi ching chong follower',
#  'really bypassing one country indonesia',
#  'hope vagina hard kondabolu never work call comedian laughing loud offended per usual rip apu boycott cunt',
#  'lmfaoooooooooooooooooo link send retard partner retard',
#  'dumb nigger gene join party actively trying exterminate',
#  'dez go nigger somewhere else',
#  'learn use comma twat',
#  'votary stfu enjoy shithole full people shithole country',
#  'go dumb as afro american',
#  'guy called spic work hope jaw heals tomorrow try',
#  'backpacking travel guide burkina faso africa trot',
#  'black people become conservative mean go full retard mean politics changed',
#  'afro american bar two hour done called ft time people watching remembered',
#  'month dla finally reissued license atos vagina reported',
#  'right nintendo japanese brand going full retard',
#  'even funny retard',
#  'steve guy fucking retard',
#  'pace game first name retarded',
#  'absolute mongoloid set hand',
#  'young one freaking',
#  'definitely country shithole',
#  'whatever coming clip fully loaded fuck faggot',
#  'finally people waking undocumented migrant new voting bl',
#  'sinead eight good reason aussie rag head mean best',
#  'holy shit lake charles la attractive woman call slut texting',
#  'hitter andslobertstakes fuck managing mongoloid idiot hell',
#  'ramachandra fun reindeer hindu name secularism leftist medium propaganda',
#  'wonder long till retarded chinese start flocking tweet start',
#  'stupid speech retard free dub',
#  'feminazi hillary locket',
#  'get nuke though retard',
#  'harder wasnt nigger hating vagina whatever would blow right game',
#  'dont know ching chong much thou',
#  'whole new low calling victim sexual assault feminazi even hu',
#  'ugly please kill faggot',
#  'need answer make fine as dyke',
#  'say nigger give pas',
#  'lmfao somebody get afro american seat',
#  'dream find comfort christianity go back come dream stay touch',
#  'use mean cool k nigger',
#  'idiot realize mass migration bring disease',
#  'care undocumented migrant american',
#  'went full',
#  'rondo retard laughing as kill',
#  'fucking vagina',
#  'une association quit vain en aide aux migrant',
#  'fuck want literal retard',
#  'thank svenskeren retarded progression wasting early invade broad',
#  'lot ya sound dumb retarded whatever personally none ya opinion ever mattered',
#  'sleep deprived hungry free pas cunt',
#  'bbc news nauru refugee island',
#  'retarded',
#  'poor sweden turning shithole country euro fruit want help',
#  'daughter jew simplistic retard',
#  'hoe dumb stupid retarded want know',
#  'many board bored mongol could hoard slut rhetorical',
#  'mongol heart',
#  'perhaps regardless attack global south refugee want non violent felon',
#  'breaking authority arrested man connected suspicious package',
#  'come back wear shirt look like nanak carpet money vagina',
#  'kidding rowling tory vagina going',
#  'would low iq believe everything government say plain retarded believe enemy',
#  'feminazi female counterpart whatever surely would condone be',
#  'especially feeling sabot evening baby faggot skeptical annoyed undecided uneasy hesitant',
#  'suspicion upstairs old chinaman neighbor feigning mental illness since year ago slamming',
#  'twat',
#  'game till faggot',
#  'oh fuck vagina come back nasty injury scored twice leave lad alone mary little',
#  'noncing jake vagina',
#  'literally called nigger type',
#  'always handful vagina waffle',
#  'shut retard',
#  'look like faggot',
#  'yeah cunt draw',
#  'idiot administration might want believe mongol horde',
#  'fucking retard apparently',
#  'ever zoe leonard want dyke',
#  'clearly drunk twat hearing one kid distraught saying dad punch',
#  'go work afro american',
#  'crap tired realized response got posted wrong profile twat haha',
#  'dropping shit girl drink ugly as faggot want hand',
#  'political correctness turning country shithole tool far left extremist divide',
#  'got number sad vagina',
#  'said vagina',
#  'matter rag head killed rag head',
#  'get unit last night correct make vagina care fuck aberdeen',
#  'trump want immigrant demo',
#  'reply nigger',
#  'mongol',
#  'glenn huddle rushed hospital collapsing god eh glenn vagina past',
#  'retarded',
#  'many cunt would cult cunt cult cult cunt could vagina cult',
#  'get life retard',
#  'despicable zionazi bastard bd freepalestine freeway coward netanyahu zionist israel',
#  'game retard',
#  'shithole country',
#  'one say spic sick',
#  'undoubtedly best center half premier league history possibly biggest vagina premier league history',
#  'anti ad man pilgrim screw shirt lambastes giving tax money immigrant guy youre',
#  'chapter discus president obama signed change mental retardation intellectual',
#  'thanks love retard',
#  'bro love nigger',
#  'ask faggot',
#  'oswald dyke',
#  'q est come merkel et tousles actress en europe time le migrant home element pour senior c',
#  'convinced mum upgrade nbn fucking finally vagina',
#  'yes yes whatever need rid toxic feminazi trying destroy men',
#  'beauty living shithole country live post office broken device would never',
#  'get called spic right back',
#  'shithole country haiti zimbabwe kenya white man live work service',
#  'nigger vote way',
#  'go back country stay hotel really country',
#  'laughing loud dodger retarded haha going tonight might questionable dodger fan going get drunk looking fade haha',
#  'year old ry fucking retard',
#  'andy keogh need kick vagina aye mover',
#  'know poorly irish immigrant treated right came',
#  'total idiot accuser feminazi never trumpet admit dr',
#  'dear israel whatever still intellectual terrorist inside country enjoy backing pseudo',
#  'remember day called wetback spick spoke spanish good ole day laughing loud',
#  'laughing loud salty great twisting multiple tweet trump triggering twit twat guy',
#  'currently accepting wolf refugee door open rubio plenty sida doth provide',
#  'someone take prick head vagina interviewed',
#  'bunch frat boy looking guy walked loud obnoxious taking selfies making joke fucking wilting laughing loud',
#  'como upon truth truth hurt refugee',
#  'silly vagina',
#  'something completely retarded',
#  'thick as dyke dancing dude went behind started grinding kept dancing though',
#  'bad nigger',
#  'cant listen nigger music',
#  'thank friend daily reminder unfollow google retarded anything',
#  'enjoying mean cool k vagina used nowt like bit plain',
#  'webcam week starter pack',
#  'mexican looking as mongoloid as bot',
#  'everyone point laugh retard',
#  'welcome family ching chong',
#  'retard want take uk hit line',
#  'horrible little cunt sorry mean cool k needed hope get banned life',
#  'anti semitism betokens retarded frederick engels',
#  'received first go back country whatever bringing champagne',
#  'sport end tie percent retarded',
#  'fault shut ching chong bitch',
#  'everyone deletes post apologize jason said leftist po oh slut',
#  'fuck spic',
#  'talk like faggot wish son car beat fucking as',
#  'getting called faggot walk home',
#  'alright nigger',
#  'afro american hairy pussy video classic mother fuck son jayden',
#  'thing gained lost retarded free speech user like robert bower possibly',
#  'naan volunteerafrica wildlife conservation friday animal chat',
#  'kevin gate president retarded',
#  'turkish president liar hate america fun rag head suck big time',
#  'ching chong let u go play big bong ping pong thank ok bye',
#  'ching chong bing bong let fuck little chink',
#  'know drink hater shut highway faggot eagle bum hey lip fuck soul move',
#  'fuck vagina',
#  'get mean cool k nigger simple',
#  'lobby childhood called wetback spic many time',
#  'um trump referred country shithole real',
#  'odd vagina',
#  'much want bet oil better year put money mouth little vagina tester',
#  'fucking stupidest vagina planet',
#  'afro american show really believed love meek keep beautiful head king',
#  'someone turn ching chong friend',
#  'lemotdujour retard',
#  'people shithole country everyone call mob really wish people',
#  'let u get retarded',
#  'people insult asian chong ching forever burning hatred',
#  'ching chong',
#  'please go back country pretend straight',
#  'parent ban unaware raising vagina latest daily mash',
#  'calling acting twat',
#  'afro american beta keep shirt whole episode team',
#  'please go back country disgraceful start campaign honest pm uphill',
#  'fake spic ew',
#  'cunt idiot',
#  'hi faggot love trying cure depression staying away yamaguchi haha hawaii sudoku',
#  'vagina played nakamura winger ana refusal play',
#  'second auburn last year mongoloid',
#  'axl retarded movie ever seen far story',
#  'lobov fight like actual retard',
#  'literally see birthday fucking mongoloid',
#  'shake hand ref retarded moncton',
#  'lucy lumberjack',
#  'longer united state trumpist shithole country later woman',
#  'big dyke energy',
#  'help roof absolute vagina nfc',
#  'crap need protest border cannot let people shithole country ruin culture',
#  'better mean cool k disrespect describe jensen especially play le slut retarded',
#  'low key thought power box pc slut pc retarded',
#  'maybe kp pipe right field nigger',
#  'dying tonight catch going full retard kayo set',
#  'laughing as retarded tell go outside walk inside',
#  'count californian pretty retarded',
#  'done punched bitch face calling esco spic even play race card',
#  'lmfaooo fucking ivan retard',
#  'know call kevin faggot dorm mad',
#  'thanks shithole country',
#  'love big dick cumming as faggot whore',
#  'think lap policy refugee climate change',
#  'racist notice always nagger spic pushing drug sometimes',
#  'hi little nigger',
#  'namibiaholidays travel guide tip review africa tourism frizemedia via',
#  'help nigger help nigger help anger',
#  'maybe open border allowing people shithole country value life',
#  'goodbye faggot travel',
#  'highkey reason want leave shithole country current political awareness',
#  'vagina trying hack twitter fuck right',
#  'ching chong chang ching whatever bitch',
#  'oh whatever go classic think found terrorist',
#  'going talk probably work retarded going say keep telling stooped laughing loud',
#  'cant wait go bulgaria soon get called nigger someone dad',
#  'news country trump would call',
#  'intellectual terrorist',
#  'also speaking ching chong',
#  'inspired retard',
#  'yes ching chong course',
#  'extremely looking neighbor braking like guy need go back country',
#  'aryan nation lost whole organization retard went',
#  'little cousin said look like dyke uh oh',
#  'cant count illegal alien deported faster ever',
#  'spic',
#  'retweet think god vagina',
#  'seem care undocumented migrant dreamer criminal child indigenous black',
#  'drinking pepsi mongoloid skull pondering feminist issue',
#  'deranged old whitetail hate okay white',
#  'reason people want use ethnic slur reason people want say faggot bad people want',
#  'hope get eaten one stupid ugly bitch karma get end evil brained twat',
#  'bantering leicester chopper crash vagina posted blocked sure sign',
#  'hilarious want competition problem illegal alien taking job pri',
#  'laundry cunt everything cunt',
#  'tweet ching chong',
#  'thing faggot hot',
#  'someone called ching chong bitch even though live u',
#  'wish never laid eye vagina hoop ana',
#  'helper losing battle soon war descent shithole country gaining momentum',
#  'maybe lied trump use shithole country',
#  'retard happy face smiley mean time',
#  'like fucking vagina damage heal ran biotic energy',
#  'boyfriend retarded guess',
#  'simply copy paste following text youtube video description box',
#  'order help increase booklet downloads would great storefront youtube account could display following text description box uploaded youtube video',
#  'booklet downloaded time counting',
#  'click free download colorfully illustrated page e book zionist engineered intentional destruction western civilization',
#  'click download bad green banner link',
#  'booklet updated',
#  'downloads',
#  'simply copy text link paste description box youtube video',
#  'thank advance download youtube description box info text file hyper text transfer protocol www medium fire com download booklet description box info text',
#  'jew certainly stupid seems think black kill alongside every white get dirty hand muppet',
#  'thank info definitely look',
#  'hope room one excited',
#  'came across piece garbage',
#  'comment say sa',
#  'die atwood cookie thumped official video youtube',
#  'white range million',
#  'believe higher since read report especially white free state counted latest census',
#  'thank posting story',
#  'think write book well',
#  'always considered teaching one profession would like get neighborhood like never kid like disgust',
#  'sad thing white student school act like',
#  'guess stick homeschooling kid',
#  'randy black expert right teach sociology star trek credited class student actually pay',
#  'wonder young people ca get job',
#  'take underwater basket weaving course worthwhile skill account angry still favorite comment',
#  'old tarzan movie zulu king kong many image',
#  'national geographic magazine early replete color photo african villager',
#  'dr albert schweitzer two hour documentary slut shown movie theater everywhere',
#  'think vhs tape available amazon',
#  'god often pale skin blue eye suppose literacy valued highly cultural intelligence',
#  'girl start talking guy middle lip start moving',
#  'slut checking line bad actor ca help',
#  'whole situation start become really bizarre',
#  'slut right sector supporter start sound fact israeli agent',
#  'know support anymore',
#  'read many post saying israel give training u law enforcement',
#  'remember boston marathon bombing watching fox news said law enforcement slut consulting israel advice',
#  'believe dog would like get far away possible',
#  'free north carolina peterson particular vikinginme',
#  'according section see job area given people well thanks posting',
#  'greece need man like adolf hitler perfect time start national political movement free country zionist banker',
#  'image first week freeman court judge bow sovereign canada youtube freeman court judge bow sovereign canada',
#  'watch hollywood movie',
#  'know chris rock subsequently hated long time',
#  'pathetic little chimp',
#  'declaring war innocent white population nation could easily justified anyone slut white nationalist',
#  'seeker truth start watching benjamin freedman speaks video youtube',
#  'com watch hxbcyxjgm move watching loss liberty film youtube',
#  'com watch watch minute obama apac youtube',
#  'com watch entire myron pagan video youtube',
#  'com watch free informative booklet video zionist engineered intentional destruction white people go youtube',
#  'com watch',
#  'wntube net com',
#  'improved site',
#  'please contribute donate',
#  'hyper text transfer protocol www tube net play php video code',
#  'try el paso texas much mud invasion river color playing crossing year round',
#  'welcome front line',
#  'folk faith family hail victory',
#  'video event worth watching see beautiful white lady screaming scum scum scum f ing scum muslim filth',
#  'protester clash military parade barking',
#  'show stupid folk',
#  'let order pizza delivered whatever try assault driver one know catch u',
#  'nice know still men pair',
#  'courage honestly appreciated',
#  'jesus christ lord indeed',
#  'nice day',
#  'suppose concept male cow female cow producing cow repeating process much understand',
#  'get mad cow disease',
#  'sooner better',
#  'yeah one ever hear',
#  'instead whatever left would tear black kid killed church bombing year ago',
#  'needed hear',
#  'unsubscribed sa thread',
#  'white folk require little time',
#  'guess mr pena forgot black speed skater gold glorified nbc every minute',
#  'sad find right also sorry inform kevin slut killed several year ago',
#  'hyper text transfer protocol www vision circle org archive three thousand eight hundred seventy html',
#  'hard time believing',
#  'friend c neither ever worked black',
#  'coworkers white asian indian paki except one guy worked mestizo week project',
#  'hundred people black',
#  'hear homeschooled kid beating public school kid spelling bee',
#  'unfortunately poor white family parent work',
#  'perhaps school district white family left could get together parent could teach kid one day per week',
#  'parent could teach weekday could teach',
#  'slut',
#  'intention ever setting foot mexico take mean cool k',
#  'excellent article jail',
#  'three four suspect death year old moore county girl repeat offender free probation',
#  'steve reed reporter three suspect charged murder year old moore county girl given suspended sentence crime free probation time slaying',
#  'perry ross schizo barnett county slut charged yesterday murder shooting death emily elizabeth haddock',
#  'fourth suspect charged murder',
#  'also charged sherwood nicholas harrison michael graham carrie van affirmative smith cameron barnett county',
#  'two suspect mr harrison mr carrie repeat probation violator',
#  'mr smith prior criminal record',
#  'mr schizo latest suspect charged killing slut arrested caliber handgun possibly murder weapon slut found car',
#  'slut also charged burglary larceny possession stolen property',
#  'four suspect held without bond moore county jail',
#  'rest story',
#  'nevermind found new page knew grid report rape',
#  'surprised came back fast',
#  'hyper text transfer protocol www oral com news local story one million eight hundred fifty thousand five hundred thirty six',
#  'obama membership prince hall black lodge become next president according guy youtube hyper text transfer protocol www youtube com watch nlfrsregii salami youtube',
#  'act negro aid right reproduce die take care kid cannot believe million crazy',
#  'hope starve',
#  'white person send single penny lift single finger help',
#  'retarded feral afro american yes feral human cannot talk occasionally pop abandoned child',
#  'walk upright human arm leg',
#  'seen afro american look undoubtedly act like',
#  'hyper text transfer protocol www occultopedia com f feral child http www long land ac uk chimp la http www occultopedia com wild peter aragon',
#  'every time see filthy comment georgia without providing fact respond',
#  'respond armenian scum stop',
#  'reason large white family encouraged day slut build population white german ravaged jewish attack hyperinflation',
#  'see nation walk front door feel like minority country',
#  'white woman go public fear assault mud',
#  'see giving',
#  'hope one day proudly say american whatever take country back',
#  'okay thread section nice watched video',
#  'obviously misunderstood would keen learn',
#  'retract always animal lack skill properly raise half human child',
#  'apologize ignorance',
#  'think anyone insinuating whatever equal non white whatever would ignore white nation',
#  'white today much white guilt laid upon feel act black sexual relation child black accepted problem white race memo',
#  'people idea came knowledge guilt attached',
#  'white knowledge little recognition slut put think would feel little pride stick white race',
#  'problem different class inside race white since whatever white joined fight non white enemy',
#  'person white christian pagan consider brother sister matter whatever profession',
#  'give example progress made skinhead klein',
#  'seems precipitous decline',
#  'around four year seen almost class divide',
#  'really like even talking fear whatever create division none',
#  'black woman london transport',
#  'racist woman rant london part youtube original racist black girl fighting south london railway balsam mitch youtube',
#  'quote trot ten million four hundred ninety seven thousand eight hundred forty three south african chocolate made overseas company based sa british swiss would mar bar taste different made sa compared one england quote would thought stuff taste different',
#  'think something type sugar sugar slut originally grown',
#  'way recall seeing mar bar',
#  'never drink diet anything either aspartame water fish',
#  'try avoid gmo stuff since label stuff hard',
#  'need avoid high fructose corn syrup bad made good morning corn',
#  'also need avoid anything soda',
#  'pesticide fresh fruit veggie',
#  'non edible chemical processed sometimes processed food',
#  'end safe thing eat grass lucky enough garden grow food space hope hell government chemical spraying',
#  'hell whatever deliberately poisoning surprised whatever lasted long',
#  'kept check whatever living actual planet ape soon',
#  'youtube xa kenya hacked death panda front film crew xc rim',
#  'racist attack black young white girl france',
#  'afro american holding camera laugh glee dailymotion aggression racist contra one file blanche france one video news politics',
#  'happens popeye run chicken youtube popeyes breakout ghetto',
#  'zero contain lot profanity forewarned',
#  'afro american rainforest music',
#  'click video comment full self hating white youtube aka rainforest people yodelers',
#  'non muslim michigan high school student wear hijab school class lesson explore religion identity pamela geller atlas shrug',
#  'able finish watching even one video',
#  'soon hear uttering monkey gibberish feel like smashing computer screen fist',
#  'would expensive',
#  'hope catch like word',
#  'anyone want post forum feel free',
#  'hard average white see disenfranchisement let alone realize planned',
#  'much disenfranchisement destroying white cultural identity pride',
#  'contributing participating anywhere opportunity instill pride white ethnic heritage even white american ethnic heritage go long helping recognize taken away',
#  'seen crap thought fuck',
#  'picture baby monkey save rainforest commercial whatever',
#  'thing holding u back traitor billion anti european people earth flourished technology',
#  'thanks saving picture one saw slut black guy looking laptop white girl sitting next laughing hanging also looking laptop show slut laptop',
#  'living room sitting couch implying couple',
#  'really sad many white denial normal even care actually happy coming',
#  'sex sleaze condensed shelf check line get hour television hour television lethal spirit',
#  'husband tom brady good looking white nordic guy photo white child',
#  'actually celebrate black history month',
#  'dream one day black occupation america history',
#  'pathological killer',
#  'jew poisoning well since biblical time',
#  'wonder whatever bad shape tribe charge white house congress',
#  'jew represents snake',
#  'need cut head rest problem crumble away ease',
#  'hate see beautiful white female become victim sick violent merciless animal',
#  'separation answer',
#  'white american white european child',
#  'amish group white large family',
#  'honestly better idea private school people average parent poor teacher',
#  'muslim ultra strict racialist private school world white',
#  'prison kike get food regular prison population get',
#  'hell care kosher',
#  'local diamond hilton situated sunny beach',
#  'whatever care alaska white land',
#  'whatever concerned dog controlling u russia',
#  'white european american grow set ball deport black brown animal country',
#  'another error update video photo video hyper text transfer protocol video google com video play doc id five quintillion two hundred sixty eight quadrillion eight hundred ninety four trillion five hundred ninety seven billion seven hundred ninety four million two hundred seventy seven thousand thirty one video fascinating conversation dr alfred yearling dr duke',
#  'kris roman kristen dr alfred yearling dr david duke theory van roy frederik ransom andreas thierry stefano gas',
#  'robert sticker dr david duke gunther van den en dr david duke euro u',
#  'euro u great europe gibraltar vladivostok',
#  'hyper text transfer protocol www error org',
#  'would done instead',
#  'ignore genocide serb turn back people',
#  'traitor',
#  'woodland rain oak forest',
#  'finn mixed swede got blond hair blue eye ethnical finn look like tatar dark hair dark eye short height round face',
#  'reason alcoholism take around one hundred fifty thousand life every year',
#  'aid around twenty thousand every year',
#  'emmigration around fifty thousand one hundred thousand per year',
#  'heart disease around one hundred thousand per year',
#  'high mortality rate like country war',
#  'lowest birthrate world',
#  'hyper text transfer protocol www guardian co uk russia art seven hundred seventy two thousand one hundred seventy five zero html attack putin',
#  'audience clap till hand numb',
#  'telling worthless oh b like cheney cheap word crocodile tear',
#  'long loved tchaikovsky ballet mussorgsky opera enjoy russian traditional music well',
#  'slut recently zaporozhye ukraine famous cossack enclave opportunity dine cossack restaurant listen traditional cossack music played live',
#  'listening music brings back memory visit russia ukraine',
#  'keep telling people thing like never believe',
#  'want show thread',
#  'great',
#  'slut kveldulf saw fit open unnecessary comment',
#  'go work',
#  'hispanic woman threw year old granddaughter several story death walkway shopping mall hyper text transfer protocol www com video twenty five million nine hundred sixty two thousand one hundred thirty six index html afro american police arrested year old said burglarized home thanksgiving weekend',
#  'jacksonville police said brian williams broke home braddock road family slut town baked brownie drank orange juice surfed porn website loaded victim car bottle liquor',
#  'hyper text transfer protocol www com news twenty five million nine hundred seventy six thousand nine hundred fifty five detail html',
#  'sex male race black oh b height weight eye brown hair black custody misdemeanor count criminal trespass deg dude look like old version cornelius planet ape',
#  'site odin rage host picture zip file somewhere else like velocity com odin rage give much room',
#  'denial normal want ruin spirit mood russian part orthodox christian different day christmas',
#  'think u',
#  'communist party slut almost jew kill gentile stood property jew communist wanted',
#  'hyper text transfer protocol www new nation vg forum show thread php p three hundred twenty five thousand nine hundred ten coach accused fondling student mother alert deputy finding note posted updated est pedophile alert robert bennett hyper text transfer protocol www clickorlando com education detail html',
#  'got turned website friend mine',
#  'show interesting statistic jew rat',
#  'hyper text transfer protocol ifamericaknew org',
#  'sort like black computer genius appears ubiquity television cinema',
#  'know reply probably never met black professional slut exclusively sale',
#  'ever heard death mask franco',
#  'one day seen one bay sure authenticity mask',
#  'group sweden genuine thief steal money never send good order',
#  'swedish comrade tell',
#  'white look somewhat average white swedish girl think',
#  'swede hide best looking female',
#  'must say thread possibly dy great fear without action die along rise multiculturalism',
#  'norwegian uncle visiting shared u thing christmas celebrated norway',
#  'also talking person denmark learned gingerbread dancing around tree various custom dinner place present tree desert dance around tree open present',
#  'found pretty interesting hope gdelig',
#  'ca wait tomorrow',
#  'actually written post last summer cancel trip okay every body cool l shane',
#  'laughing loud okay give never heard specific mean cool k slut dictionary',
#  'since really sure allen horace england ca say svenja academic oralist',
#  'think bit wrong one since race nation learn',
#  'make damn angry swede ca see',
#  'black brown destroying sweden nobody anything made made made',
#  'thing manipulated mind foreigner reckon live amongst superior pagan blood',
#  'say rotunda',
#  'figure',
#  'pretty sure ten billion sent abroad every year even though stay sweden',
#  'hmm let try viewing number asylum seeker per zero population',
#  'much important estimation',
#  'instance let u zero people legally every year canada let u zero',
#  'however per caput rate legal immigration per zero annually canada',
#  'thus shockingly canada actually achieve non white majority',
#  'denmark zero zero assuming population million good job denmark',
#  'let see get zero',
#  'norway assuming population million sweden assuming population million iceland zero',
#  'finland however used low higher denmark nearly high norway',
#  'per caput take in norway slut worst apparently norwegian cracked reply lower sweden rate',
#  'good news slut norse',
#  'black saw somali reply cross mix black arab',
#  'possible',
#  'read earlier post see still lot non white coming denmark',
#  'dare look',
#  'see grandma hair looked like year ago',
#  'eldritch went early harbor boat cancelled account rough weather',
#  'one day brother one day',
#  'seen web making new horror film called wait cannot find much',
#  'thought agreed would salem year parent want medium attention',
#  'afraid son might come find drunk bar year later try kill something',
#  'damn finland closing sweden poll',
#  'welcome anyway uric war spirit',
#  'get saying thousand non irish never contribute anything land',
#  'folk talking shoulder shoulder long time continue show loyalty respect earned',
#  'unless tourist study year two please go back russian whatever need want slav',
#  'load crap water yeah people real ireland taken non irish rubbish',
#  'hate mean cool k racist make people called racist think something wrong immigrant coming something wrong',
#  'reminds old joke',
#  'difference stop park day martin luther king day stop patrick day every body wish irish',
#  'sorry many people country stupid',
#  'feel need close prison full terrorist people aided killing soldier scatter around world',
#  'pole decide leave therefore devastating irish economy every man dog telling u potential ramification welfare scrounging visitor far ashore',
#  'slut asking link say banning celtic cross thanks link check',
#  'march showing pride culture guy go could try contact people know different city see willing',
#  'good luck noremorsenoregrets hopefully good news job let u hope become another figure stat',
#  'posted thread storefront ireland week english hooligan slashing irish men throat thread disappeared without explanation',
#  'crude drawing swastika wall spray paint make neutral people associate nazi common lowlife scum',
#  'mod also change thread title say want people showing day late',
#  'watching video make feel like going explode hatred creature',
#  'feel mix intense hate depression whatever let thing degenerate far',
#  'know reply almost exclusively nigerian asylum seeker',
#  'shop food shop bus train station clothes shop sell full assorted gangster rap crap',
#  'filth sectarian british song irish folk song sort scum wrote admire filth place forum let alone irish forum',
#  'thanks limerick pit put planner doubt total restoration fact',
#  'early punk scene slut always seen decked union flag blazer sudden instant nationality transplant',
#  'well done least someone getting as taking action rather sitting behind computer cyber warrior hope others follow suit',
#  'fellow white man rape daughter kill brother let go white',
#  'disgrace sister waiting list year giving away house scumbags',
#  'info site date interesting information group ore come gone year',
#  'hyper text transfer protocol www thinking ac il anti semitism ireland',
#  'younger limerick crowd say gang morose regular fight pole go around ten meet hell break loose like east germany pole working class irish',
#  'slut away weekend get around posting blood group see bother anyway way blood group oh',
#  'church ireland archbishop dublin called amnesty immigrant ireland five year without status resolved',
#  'hyper text transfer protocol www post post page p sqq asp',
#  'thanks seem like much putting one leaflet noticeboard get lot people talking',
#  'joke whatever high standard education system ireland',
#  'good anywhere world',
#  'thankfully see camp go ahead year',
#  'unfortunately whatever missed last year year occasion definitely make',
#  'beautiful scenery music campfire good true company',
#  'looking forward',
#  'read recently cold black white print slut around zero nigerian ireland say close zero',
#  'true',
#  'people want foreign aid increased people walk past irish people living rough street care old people government ignores',
#  'cd gave away let see get copy',
#  'denial normal think supremacist would ever able build force resistance irish republican mate',
#  'look jealousy',
#  'lie lie lie',
#  'irish men rosewood beautiful',
#  'love darker hair skin eye',
#  'stunning kiss',
#  'article say went mainstream schooling think must played role drug proscribed health problem',
#  'active community need get net find',
#  'use pm get touch',
#  'could begin tell people multicultural stuff wrong without hated fellow people',
#  'yeah slut slut going school calgary problem like kid whatever child usually',
#  'chapter right fraser valley near vancouver looking open chapter canada',
#  'native driving around truck year ago',
#  'nothing unusual except said back window',
#  'work harder white boy brother need new truck',
#  'game similar first described evil grin fifa british fa',
#  'way led believe football soccer slut invented somalia ad',
#  'pig bladder used football made camel doings',
#  'like said earlier english subjected far worse campaign indoctrination rest u',
#  'admit think ever met briton english must know something know good',
#  'base post fact live hundred yard house slut born never felt desire suck milk anything english nipple',
#  'mind eye small face youtube',
#  'would even use anything man say winston churchill reason whatever mess first place bastard shot',
#  'think',
#  'vision left christian screeching meek shall inherit earth member peaceful religion go chopping humor',
#  'know',
#  'would want see pollution spread gene pool',
#  'thanks god chosen go kind',
#  'followed link bdp tried check policy shown lot latin translates total gobbledygook',
#  'happy stop david day welsh compatriot',
#  'one time enemy eternal ally english',
#  'today assembly diversity whatever embrace culture learn',
#  'one mention burn night culture',
#  'reply happening school',
#  'simple truth sadly preparing future marxism offer',
#  'denial normal ridiculous',
#  'advocate independence join another sovereign nation wale would hypothetical scenario',
#  'operator gone sunnier clime couple week close explain return',
#  'denial normal care much football day sincerely hope team called england get hiding wearing new serbia shirt tournament come serbia u proud',
#  'anyone else fed people using called race card tell u',
#  'buying gun bullet',
#  'fault bnp run gangster',
#  'yeah edinburgh slut secondary school class full black pakis half could hardly speak english',
#  'look get disgust regular happily carry walking laugh think showing picture afro american kid poster without burger going make want give money',
#  'yeah heard one whatever came africa anywhere dose matter answer whatever evolved better',
#  'yes dying whatever could beat problem voting bnp next election',
#  'hello friend forum',
#  'sign placed council stating ball game yes playing football',
#  'playing scooter bike noisy toy right outside window',
#  'hardly hear television',
#  'got bad literally outside dog slut lead',
#  'p stayed end stupid look face',
#  'minute took dog walk',
#  'must black others coming join',
#  'slut one white child amongst',
#  'oh yes round whatever new neighbor moved',
#  'foreign course',
#  'open landing window earlier stench cooking slut overpowering',
#  'thankyou allowing vent feel angry',
#  'wrote truth know white none know post confirmed white',
#  'hand point anything posted absolute truth',
#  'every time see black security guard either phone professionalism whatsoever',
#  'yes homosexual degeneracy foisted upon silent majority',
#  'dare speak country supposed free speech reply labelled bigot',
#  'hey really new browsing forum got account decided become active online day day life',
#  'follow cycle water whatever drink already toilet time nothing new',
#  'agree barrrytheanglosaxon many point oh',
#  'english team white',
#  'one thing like football among football fan many white patriot right wing ultras u youtube',
#  'cannot understand people britain love much breed non white keep shocking go',
#  'never seen thing country',
#  'something mysterious must happening',
#  'say whatever reply going die anyway okay white people going replace u',
#  'coming right',
#  'sugar bowl lemon side',
#  'pleasure make acquaintance madam',
#  'competition television get alien looking black put white woman',
#  'light brings would imagine like claim accusation wildly exaggerated',
#  'mean',
#  'better hated loved',
#  'andre gide french critic essayist novelist',
#  'yeah whatever could amount black rapist nordic country privileged enough',
#  'yes true reminds incident muslim extremist abuse royal anglican troop afghanistan return barking london youtube',
#  'surely got town town see minority white white supposed least million hard showing',
#  'personal card teacher johann aretha upper silesia village kaminietz near gleiwitz tossed twice',
#  'name village slut changed drama stein third reich today called kamieniec poland',
#  'first moldavia',
#  'second really hope one day chauvinist try take transylvania u posed ring bell bail ring bell seminar ring bell',
#  'budapest treason ring bell military still vastly superior always',
#  'taking ancestral homeland u ever',
#  'oh great',
#  'enjoy brit come tell bulgarian everything need know',
#  'girl indeed amazing',
#  'whatever could much sport medal politician authority greedy bastard',
#  'hi everyone slovenia utterly hate every living muslim world despise even dead one',
#  'whatever somebody monitor protest around people despite claim usually hundred demo',
#  'friend life gdansk told almost everyone city slut white except foreign student chinese man owns dive bar',
#  'enough interest either side reply unification attempted',
#  'besides transnistria issue solved hard fact romania simply economic power accomplish reply unification',
#  'gay issue practically non existent romania even though local gay ngo organizes yearly pride parade bucharest',
#  'fact year event going weekend',
#  'never hundred people attending parade many non romanian gay arrived western europe',
#  'vast majority romanian gay simply exist except television',
#  'feel great appreciation admiration polish people get sad hear white brother speaking ill pole',
#  'bulgarian slavic perhaps time rest seek new name u used ethnonym first dig',
#  'ukraine russia poland romania fake ukrainian',
#  'p someone else cabin according cabin romanian listen hungarian music',
#  'hyper text transfer protocol www republishers com four seys ok text pdf molecular genetic method supported observation relatively small difference hungarian indian group central european differ',
#  'source kama raj int j hum genet human chromosomal polymorphism hungarian sample data orally giorgi',
#  'semmelweis university department forensic medicine budapest hungary',
#  'maybe storefront consider documentation letting gypsy group join kicking hungarian',
#  'let concern anti good video barely view likely watched anarchist',
#  'like certainly ireland especially idea littered memorial even statue red terrorist',
#  'top ten movie banned ireland ten movie irish censor blocked ireland cinema top ten movie banned ireland ringcentral',
#  'wonder retaliation loyalist mob attacking catholic home little interference psi last week',
#  'stumbled accident absolute savage yet liberal woman saying great multiculturalism whatever le ta la gram france montpellier',
#  'start',
#  'hopefully get intimidated enemy land freedom antifa scum',
#  'okay go logic mean reply willing give piece land',
#  'genius',
#  'know much event slut crowd day',
#  'could almost see video',
#  'thank thea charles martell',
#  'think heard name storefront radio honored',
#  'god bless either case',
#  'power want white dubbed afro american blood',
#  'need sent back area along jew control politician',
#  'slav live west ever seen western devil obsession american football',
#  'tired',
#  'hope afro american beat afro american',
#  'stupid',
#  'planning little gathering remember good old day',
#  'candlelight good drink forbidden flag wall triumph de en telly',
#  'new slut wandering lady interested good oil southern man tennessee send message',
#  'hey homosex six kid great gift given race thank lucky awesome parent two',
#  'every one stop making fun people picture white family lady looking fine bad',
#  'name past',
#  'back dusty used show bar tampa band slut playing get onstage u sing johnny good long haired country boy two song knew',
#  'first kiss slut behind church door third grade',
#  'year later whatever got married',
#  'year later whatever split',
#  'last time kissed yesterday',
#  'hope coon got life jail death penalty best nobody ask',
#  'slut year younger would jump chance',
#  'come guy help show kid right',
#  'laughing loud pillow count mean nothing actually five',
#  'need build little fort around night',
#  'hey permit eye eye like lethal man drown',
#  'hi cal many others like minded people',
#  'pm want chat',
#  'try link',
#  'click picture wait load',
#  'lot old lot new one adding soon',
#  'never herded one even actually happening would think would last either get along never cannot force',
#  'hamilton looking people put society crap email hammer smashed skull hotmail com',
#  'think post one placed profile euro date day ago',
#  'use one part',
#  'thanks everybody input',
#  'everyone msn get manner picture never put go picture year ago small angie week ago haha robin',
#  'new hole scene connecticut make sure find real people hole fake well played people',
#  ...]

# %% [markdown]
# # Creating a one_hot representation

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# To create a one_hot representation
voc_size = 500
one_hot_repr = [one_hot(word, voc_size) for word in corpus]
one_hot_repr

# %% [markdown]
# # Using padding techniques (pre-padding) - Embedding Representation

# %%
sent_length = 20

embedding_docs = pad_sequences(one_hot_repr, padding = 'pre', maxlen = sent_length)
embedding_docs
# Out:
# array([[  0,   0,   0, ..., 484, 364, 246],
#        [  0,   0,   0, ..., 410, 169,  44],
#        [  0,   0,   0, ..., 423, 178, 157],
#        ...,
#        [  0,   0,   0, ..., 327, 177, 111],
#        [355, 289, 341, ...,  72, 359, 104],
#        [  0,   0,   0, ..., 379, 327, 104]], dtype=int32)

# %% [markdown]
# # Creating a model and and an architecture

# %%
embedding_features = 40

model = Sequential()
model.add(Embedding(voc_size, embedding_features, input_length = sent_length))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 20, 40)            20000
#
#  lstm_1 (LSTM)               (None, 100)               56400
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 76501 (298.83 KB)
# Trainable params: 76501 (298.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X_final = np.array(embedding_docs)
y_final = np.array(y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, random_state = 1234)

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 10)
# Out:
# Epoch 1/10
# 17019/17019 [==============================] - 134s 8ms/step - loss: 0.5620 - accuracy: 0.7046 - val_loss: 0.5465 - val_accuracy: 0.7159
# Epoch 2/10
# 17019/17019 [==============================] - 120s 7ms/step - loss: 0.5404 - accuracy: 0.7211 - val_loss: 0.5345 - val_accuracy: 0.7242
# Epoch 3/10
# 17019/17019 [==============================] - 120s 7ms/step - loss: 0.5279 - accuracy: 0.7292 - val_loss: 0.5268 - val_accuracy: 0.7282
# Epoch 4/10
# 17019/17019 [==============================] - 115s 7ms/step - loss: 0.5167 - accuracy: 0.7361 - val_loss: 0.5198 - val_accuracy: 0.7325
# Epoch 5/10
# 17019/17019 [==============================] - 121s 7ms/step - loss: 0.5059 - accuracy: 0.7433 - val_loss: 0.5170 - val_accuracy: 0.7358
# Epoch 6/10
# 17019/17019 [==============================] - 121s 7ms/step - loss: 0.4957 - accuracy: 0.7491 - val_loss: 0.5119 - val_accuracy: 0.7391
# Epoch 7/10
# 17019/17019 [==============================] - 121s 7ms/step - loss: 0.4848 - accuracy: 0.7566 - val_loss: 0.5116 - val_accuracy: 0.7415
# Epoch 8/10
# 17019/17019 [==============================] - 129s 8ms/step - loss: 0.4751 - accuracy: 0.7627 - val_loss: 0.5092 - val_accuracy: 0.7421
# Epoch 9/10
# 17019/17019 [==============================] - 124s 7ms/step - loss: 0.4663 - accuracy: 0.7682 - val_loss: 0.5130 - val_accuracy: 0.7418
# Epoch 10/10
# 17019/17019 [==============================] - 121s 7ms/step - loss: 0.4588 - accuracy: 0.7728 - val_loss: 0.5133 - val_accuracy: 0.7418

# %% [markdown]
# # Saving the model in pickle file

# %%
import pickle

with open("HateSpeechDetect74%.pkl", 'wb') as f:
  pickle.dump(model, f)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
y_pred = model.predict(X_test)
# Out:
# 5673/5673 [==============================] - 14s 2ms/step

# %%
y_pred = np.where(y_pred > 0.5, 1, 0)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7418167795956592

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[62412, 27758],
#        [19110, 72250]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.69      0.73     90170
#            1       0.72      0.79      0.76     91360
#
#     accuracy                           0.74    181530
#    macro avg       0.74      0.74      0.74    181530
# weighted avg       0.74      0.74      0.74    181530

# %%
test = pd.read_csv("/content/drive/MyDrive/NLP/HateSpeechDetection/Data/HateSpeechDatasetBalanced.csv")
test
# Out:
#                                                   Content  Label
# 0       denial of normal the con be asked to comment o...      1
# 1       just by being able to tweet this insufferable ...      1
# 2       that is retarded you too cute to be single tha...      1
# 3       thought of a real badass mongol style declarat...      1
# 4                                     afro american basho      1
# ...                                                   ...    ...
# 726114  i mute this telecasting and played kanye west ...      1
# 726115  but hell yeah he s not a bachelor but looooooo...      1
# 726116  great video musician but s not my musician lol...      1
# 726117  not great pop video yeah he s not a pedophile ...      1
# 726118  great video yeah he s non a paedophile lolllll...      1
#
# [726119 rows x 2 columns]

# %%
def predicting_pipeline(message):

  corpus = []

  for i in range(0, len(message)):
    result = message[i]
    # We remove all the special characters and the numbers
    result = re.sub('[^A-Za-z]', ' ', message[i])
    # We make sure it is in lower case
    result = result.lower().split()
    result = [lematizer.lemmatize(word) for word in result if not word in stopwords.words('english')]
    result = ' '.join(result)

    corpus.append(result)


  # To create a one_hot representation
  voc_size = 500
  one_hot_repr = [one_hot(word, voc_size) for word in corpus]

  sent_length = 20

  embedding_docs = pad_sequences(one_hot_repr, padding = 'pre', maxlen = sent_length)
  y_pred = model.predict(np.array(embedding_docs).reshape(1,-1))
  predictions = np.where(y_pred > 0.6, 0, 1)

  return predictions

# %%
predicting_pipeline("Hello motherfucker")
# Out:
# 1/1 [==============================] - 0s 53ms/step
# array([[1]])
